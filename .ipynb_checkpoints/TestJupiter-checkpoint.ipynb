# %% [markdown]
# ## This is Headding

# %% [markdown]
# **Bold Text**

# %% [markdown]
# # Markdown Guide for Jupyter Notebooks
#
# ## Headings
# # This is a level 1 heading
# ## This is a level 2 heading
# ### This is a level 3 heading
# #### This is a level 4 heading
#
# ---
#
# ## Text Styling
# - **Bold Text**: **This is bold text**
# - *Italic Text*: *This is italic text*
# - ~~Strikethrough~~: ~~This text is crossed out~~
# - **_Bold and Italic_**: **_This is both bold and italic_**
#
# ---
#
# ## Lists
# ### Unordered List:
# - Item 1
#   - Sub-item 1
#   - Sub-item 2
# - Item 2
#
# ### Ordered List:
# 1. First item
# 2. Second item
#    1. Sub-item 1
#    2. Sub-item 2
#
# ---
#
# ## Links and Images
# - [This is a link](https://www.example.com)
#
# ---
#
# ## Tables
# | Column 1 | Column 2 | Column 3 |
# |----------|----------|----------|
# | Data 1   | Data 2   | Data 3   |
# | Data 4   | Data 5   | Data 6   |
#
# ## Student Table
# | Name | Age | City |
# |----------|----------|----------|
# | Savinda jayasekara | 23  | Matara   |
# | Navishka punchi hewa | 27   | Nigambo   |
#
# ---
#
# ## Code
# ### Inline Code:
# This is `inline code`.
#
# ### Code Block:
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# print(greet("World"))
