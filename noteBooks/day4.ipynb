# %%
numbers = str(input('Enter Numbers: '))
numbers = numbers.split()

sorted_numbers = sorted(numbers)

print('Sorted Numbers:', sorted_numbers)
# Out:
# Sorted Numbers: ['1', '2', '3', '4', '5', '6', '7', '7', '8', '9']
